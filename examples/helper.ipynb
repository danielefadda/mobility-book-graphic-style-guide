# %% [markdown]
# # Theme Helper — Accesso Rapido ai Design Tokens
#
# Questo notebook dimostra come usare il modulo `theme` per accedere facilmente ai token senza navigare manualmente l'albero completo.
#
# ## Contenuti
# 1. **Palette di colori**: palette base, reversed, sequenziali
# 2. **Colori semantici**: brand, intent, text, background
# 3. **Font**: famiglie, dimensioni, pesi
# 4. **Introspezione**: scopri le opzioni disponibili
# 5. **Riepilogo tema**: stampa di riferimento rapido

# %%
import mobility_book_style as mbs
from mobility_book_style import theme

print(f"✅ mobility_book_style caricato")
print(f"✅ Modulo 'theme' disponibile per accesso rapido ai token")
# Out:
# ✅ mobility_book_style caricato
# ✅ Modulo 'theme' disponibile per accesso rapido ai token

# %% [markdown]
# ## 1. Palette di Colori

# %%
# Ottieni una palette base in ordine (chiaro → scuro)
teal_palette = theme.get_palette('teal')
print(f"Teal palette ({len(teal_palette)} colori):")
print(f"  Più chiaro: {teal_palette[0]}")
print(f"  Più scuro: {teal_palette[-1]}")
print(f"  Completa: {teal_palette}")

# Palette disponibili
print(f"\nPalette disponibili: {', '.join(theme.list_palettes())}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Ottieni una palette base in ordine (chiaro → scuro)
# ----> 2 teal_palette = theme.get_palette('teal')
#       3 print(f"Teal palette ({len(teal_palette)} colori):")
#       4 print(f"  Più chiaro: {teal_palette[0]}")
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/theme.py:28, in get_palette(name, reverse)
#      18 def get_palette(name: PaletteName, reverse: bool = False) -> List[str]:
#      19     """
#      20     Restituisce una lista ordinata di codici esadecimali per una scala colore base.
#      21     Gestisce l'ordinamento numerico delle chiavi (50, 100, ... 900) che nel JSON sono stringhe.
#      22
#      23     Args:
#      24         name: Nome della palette (teal, burgundy, purple, olive, gold, slate, rust, neutral)
#      25         reverse: Se True, inverte l'ordine della palette
#      26
#      27     Returns:
# ---> 28         Lista di colori hex ordinati dal più chiaro al più scuro (o viceversa se reverse=True)
#      29
#      30     Esempio:
#      31         >>> colors = get_palette('teal')
#      32         >>> # ['#a4f8ff', '#8ee2ed', ..., '#002a34']
#      33     """
#      34     try:
#      35         # Accediamo al nodo del colore (es. token.color.base.teal)
#      36         color_node = getattr(token.color.base, name)
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# ## 2. Colori Semantici

# %%
# Accesso rapido ai colori principali
primary = theme.get_color('primary')
accent = theme.get_color('accent')

print(f"Brand colors:")
print(f"  Primary: {primary}")
print(f"  Accent: {accent}")

# Colori intent (esercizio, avvertimento, etc)
exercise = theme.get_color('exercise', section='intent')
warning = theme.get_color('warning', section='intent')

print(f"\nIntent colors:")
print(f"  Exercise: {exercise}")
print(f"  Warning: {warning}")

# Colori testo
text_primary = theme.get_color('text_primary')
link = theme.get_color('link')

print(f"\nText colors:")
print(f"  Primary: {text_primary}")
print(f"  Link: {link}")

# %% [markdown]
# ## 3. Configurazioni Font

# %%
# Font props pronti per matplotlib
title_font = theme.get_font_props(family='sans', size='xl', weight='bold')
print(f"Title font (sans, xl, bold):")
for key, val in title_font.items():
    print(f"  {key}: {val}")

# Altre combinazioni
body_font = theme.get_font_props(size='m', weight='regular')
label_font = theme.get_font_props(size='s', weight='regular')

print(f"\nBody font: {body_font}")
print(f"Label font: {label_font}")

# Scopri le opzioni disponibili
print(f"\nFont families: {', '.join(theme.list_fonts())}")
print(f"Font sizes: {', '.join(theme.list_font_sizes())}")
print(f"Font weights: {', '.join(theme.list_font_weights())}")

# %% [markdown]
# ## 4. Sequenze per Grafici

# %%
# Sequenze di colori per grafici Altair/Matplotlib
rust_seq = theme.get_chart_sequence('rust')
print(f"Rust sequence ({len(rust_seq)} colori):")
print(f"  {rust_seq}")

# Tutte le sequenze disponibili
schemes = theme.list_chart_schemes()
print(f"\nSequenziali disponibili:")
print(f"  {', '.join(schemes.get('sequential', []))}")
print(f"\nDivergenti disponibili:")
print(f"  {', '.join(schemes.get('divergent', []))}")

# %% [markdown]
# ## 5. Riepilogo Tema

# %%
# Stampa completa di tutte le opzioni disponibili nel tema
theme.print_theme_summary()

# %% [markdown]
# ## Casi d'uso Pratici: Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Setup tema matplotlib
mbs.apply_matplotlib_theme()

# Crea un grafico usando i colori dal theme
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1: usa il colore semantico "exercise"
x = np.linspace(0, 10, 100)
ax1.plot(x, np.sin(x), color=theme.get_color('exercise'), linewidth=2)
ax1.set_title('Usando get_color("exercise")', fontdict=theme.get_font_props(size='l', weight='bold'))
ax1.grid(True, alpha=0.3)

# Plot 2: usa una palette per una heatmap
from matplotlib.colors import ListedColormap
palette = theme.get_palette('teal')
cmap = ListedColormap(palette)
data = np.random.rand(10, 10)
im = ax2.imshow(data, cmap=cmap, aspect='equal')
ax2.set_title('Usando get_palette("teal")', fontdict=theme.get_font_props(size='l', weight='bold'))
plt.colorbar(im, ax=ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Casi d'uso Pratici: Altair

# %%
import altair as alt
import pandas as pd

# Setup tema altair
mbs.enable_altair_theme()

# Crea un grafico con sequenza teal
data = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Value': [10, 23, 15, 30, 22]
})

teal_colors = theme.get_chart_sequence('teal')

chart = alt.Chart(data).mark_bar().encode(
    x='Category:N',
    y='Value:Q',
    color=alt.Color('Category:N', scale=alt.Scale(range=teal_colors[:5]))
).properties(
    title='Grafico con theme.get_chart_sequence("teal")',
    width=500,
    height=300
)

chart

# %%
from mobility_book_style import theme # supponendo tu abbia messo il codice lì

# Accesso immediato
primary_color = theme.get_color("primary")

# Palette pronta all'uso (es. per una heatmap o cmap custom)
teal_palette = theme.get_palette("teal")
# Output: ['#a4f8ff', '#8ee2ed', ..., '#002a34']

# Configurazione font rapida
title_font = theme.get_font_props(size="xl", weight="bold")
# Output: {'family': 'Inter...', 'size': '12pt', 'weight': '700'}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 from mobility_book_style import theme # supponendo tu abbia messo il codice lì
#       3 # Accesso immediato
# ----> 4 primary_color = theme.get_color("primary")
#       6 # Palette pronta all'uso (es. per una heatmap o cmap custom)
#       7 teal_palette = theme.get_palette("teal")
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/theme.py:44, in get_color(role, section)
#      38 """
#      39 Recupera rapidamente un singolo colore semantico senza navigare tutto l'albero.
#      40 Uso: get_color('primary', section='brand') oppure get_color('exercise', section='intent')
#      41 """
#      42 # Mapping rapido per i casi d'uso più comuni
#      43 shortcuts = {
# ---> 44     "primary": token.brand.primary.value,
#      45     "accent": token.brand.accent.value,
#      46     "text_primary": token.text.primary.value,
#      47     "text_secondary": token.text.secondary.value,
#      48     "link": token.text.link.value,
#      49     "exercise": token.intent.exercise.value,
#      50     "warning": token.intent.warning.value,
#      51     "definition": token.intent.definition.value,
#      52     "curiosity": token.intent.curiosity.value,
#      53 }
#      55 # Se il ruolo è nelle scorciatoie, lo ritorniamo, altrimenti proviamo a navigare
#      56 if role in shortcuts:
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/_tokens.py:37, in TokenNode.__getattr__(self, name)
#      35     child = self._data[name]
#      36     return child if _is_leaf(child) else TokenNode(child, (*self._path, name))
# ---> 37 raise AttributeError(f"Token '{'.'.join(self._path)}' non contiene '{name}'")
#
# AttributeError: Token '' non contiene 'brand'

# %%
import mobility_book_style.theme as theme
theme.print_theme_summary()
# Out:
# --- MOBILITY BOOK DESIGN SYSTEM ---
#
# 🎨 PALETTE BASE (9):
#    neutral, teal, burgundy, purple, olive, gold, slate, rust, special
#
# 🎯 SEMANTICA:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import mobility_book_style.theme as theme
# ----> 2 theme.print_theme_summary()
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/theme.py:139, in print_theme_summary()
#     136 print(f"   {', '.join(list_palettes())}")
#     138 print(f"\n🎯 SEMANTICA:")
# --> 139 semantics = list_semantic_keys()
#     140 for section, keys in semantics.items():
#     141     print(f"   • {section.capitalize()}: {', '.join(keys)}")
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/theme.py:105, in list_semantic_keys()
#      99 def list_semantic_keys() -> Dict[str, List[str]]:
#     100     """
#     101     Restituisce un dizionario con tutte le chiavi semantiche disponibili,
#     102     raggruppate per sezione (brand, intent, text).
#     103     """
#     104     return {
# --> 105         "brand": list(token.brand.keys()),
#     106         "intent": list(token.intent.keys()),
#     107         "text": list(token.text.keys()),
#     108         "background": list(token.background.keys())
#     109     }
#
# File ~/Git/mobility-book-graphic-style-guide/mobility_book_style/_tokens.py:37, in TokenNode.__getattr__(self, name)
#      35     child = self._data[name]
#      36     return child if _is_leaf(child) else TokenNode(child, (*self._path, name))
# ---> 37 raise AttributeError(f"Token '{'.'.join(self._path)}' non contiene '{name}'")
#
# AttributeError: Token '' non contiene 'brand'
